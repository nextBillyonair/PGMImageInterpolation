# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
limit = 9

# %%
sizes = [2**i for i in range(0, limit)]
sizes
# Out:
# [1, 2, 4, 8, 16, 32, 64, 128, 256]

# %%
features = [size**2 * 3 for size in sizes]
features
# Out:
# [3, 12, 48, 192, 768, 3072, 12288, 49152, 196608]

# %%
plt.plot(sizes, features)
