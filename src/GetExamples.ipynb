# %%
import matplotlib
import img_utils
import random
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
num = random.randint(0, 2269)
print(num)
num = 600
# painting_img = img_utils.load_img(f"../../PGMData/imgs/schilderij_43.jpg")
# painting_img = img_utils.load_img(f"../../PGMData/imgs/schilderij_2099.jpg")
painting_img = img_utils.load_img(f"../../PGMData/imgs/schilderij_{num}.jpg")
img_utils.plot_img(painting_img)
plt.savefig('../report/sample_painting.png', dpi=300, bbox_inches='tight', transparent=True)
# Out:
# 1006

# %%
num = random.randint(0, 2269)
# num = 2209
print(num)
photo_img = img_utils.load_img(f"../../PGMData/imgs/foto_{num}.jpg")
img_utils.plot_img(photo_img)
plt.savefig('../report/sample_photo.png', dpi=300, bbox_inches='tight', transparent=True)
# Out:
# 1372

# %%
num = random.randint(0, 2269)
print(num)
# num = 1993
# drawing_img = img_utils.load_img(f"../../PGMData/imgs/tekening_1084.jpg")
drawing_img = img_utils.load_img(f"../../PGMData/imgs/tekening_{num}.jpg")
img_utils.plot_img(drawing_img)
# plt.savefig('../report/sample_drawing.png', dpi=300, bbox_inches='tight', transparent=True)
# Out:
# 2186

# %%
num = random.randint(0, 2269)
print(num)
# num = 919
print_img = img_utils.load_img(f"../../PGMData/imgs/prent_{num}.jpg") 
img_utils.plot_img(print_img)
plt.savefig('../report/sample_print.png', dpi=300, bbox_inches='tight', transparent=True)
# Out:
# 1722
