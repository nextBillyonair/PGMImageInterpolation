# %%
import img_utils
import matplotlib.pyplot as plt

# %%
img = img_utils.load_img(f"../../PGMData/imgs/schilderij_1507.jpg")

# %%
img_utils.plot_img(img)
# plt.savefig('../report/ori_img.png', dpi=300, bbox_inches='tight', transparent=True)

# %%
size = 64
new_img = img_utils.downsize(img, size)
img_utils.plot_img(new_img, size)
# plt.savefig('../report/decimated_img.png', dpi=300, bbox_inches='tight', transparent=True)

# %%
pixel_size = img.reshape(-1, 3).shape[0]
print(pixel_size, img.shape)
img_utils.plot_pixels(img, title="", N=pixel_size, s=7, alpha=1)
# plt.savefig('../report/ori_pixel_plot.png', dpi=300, bbox_inches='tight')
# Out:
# 249000 (498, 500, 3)

# %%
print(new_img.reshape(-1, 3).shape[0], new_img.shape)
img_utils.plot_pixels(new_img, title="", s=7, alpha=1.0)
# plt.savefig('../report/decimated_pixel_plot.png', dpi=300, bbox_inches='tight')
# Out:
# 4096 (12288,)
